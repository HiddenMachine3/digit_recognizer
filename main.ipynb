# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from pprint import pprint
import numpy as np
# Out:
# 2024-01-21 14:05:10.384128: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
handwritten_digits =  tf.keras.datasets.mnist.load_data()
(train_imgs, train_lbls), (test_imgs, test_lbls) = handwritten_digits

# %%
def display_ascii_with_color(array):
    ascii_array = []
    for row in array:
        ascii_row = []
        for element in row:
            brightness = int(element / 16) + 232  # Calculate brightness value for ANSI color
            ascii_row.append(f'\033[48;5;{brightness}m \033[0m')  # ANSI color output with brightness
        ascii_array.append(''.join(ascii_row))
    return '\n'.join(ascii_array)

# %%
ascii_output = display_ascii_with_color(train_imgs[0])
print(train_lbls[0])
print(ascii_output)
# Out:
# 5

# %%
train_lbls = to_categorical(train_lbls)
test_lbls = to_categorical(test_lbls)

# %%
model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(30, activation="sigmoid"),
        tf.keras.layers.Dense(10, activation="softmax"),
    ]
)

model.compile(
    optimizer="adam",
    loss=tf.keras.losses.CosineSimilarity(),
    metrics=["accuracy"],
)

model.fit(x=train_imgs, y=train_lbls, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: -0.7861 - accuracy: 0.7850
# Epoch 2/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.8725 - accuracy: 0.8655
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.8786 - accuracy: 0.8689
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.8891 - accuracy: 0.8779
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.8932 - accuracy: 0.8811
# Epoch 6/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.8978 - accuracy: 0.8860
# Epoch 7/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.9012 - accuracy: 0.8885
# Epoch 8/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: -0.8970 - accuracy: 0.8836
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.8999 - accuracy: 0.8877
# Epoch 10/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: -0.9048 - accuracy: 0.8928

# %%
ascii_output = display_ascii_with_color(test_imgs[0])
actual_number = test_lbls[0].argmax()
predicted_number = model.predict(np.array([test_imgs[0]])).argmax()
print("actual :", np.argmax(test_lbls[0]),", predicted :", predicted_number)
print(ascii_output)
# Out:
# 1/1 [==============================] - 0s 71ms/step
# actual : 7 , predicted : 7
